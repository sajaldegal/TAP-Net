# %%
# Pseudo-Label Generator with Contour Fitting (Ellipse Only)
import os
import cv2
import torch
import numpy as np
import pandas as pd
from PIL import Image
from torchvision import transforms
from model_teacher import TeacherNet, denormalize

# Paths
VIDEO_FRAMES_DIR = "G:/Sajal_Data/Obj_4_Code/TAPNet_Dataset/video_frames"
OUTPUT_MASK_DIR = "G:/Sajal_Data/Obj_4_Code/TAPNet_Dataset/contour_masks"
OUTPUT_CSV_PATH = "G:/Sajal_Data/Obj_4_Code/TAPNet_Dataset/contour_labels.csv"
MIN_MAX_PATH = "biometric_min_max.csv"
MODEL_PATH = "teacher_model.pth"

os.makedirs(OUTPUT_MASK_DIR, exist_ok=True)

# Device and model setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = TeacherNet().to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

# Transforms
transform = transforms.Compose([
    transforms.Grayscale(),
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

label_map = {0: "head", 1: "abdomen", 2: "femur"}

results = []

for img_file in sorted(os.listdir(VIDEO_FRAMES_DIR)):
    if not img_file.lower().endswith(('.jpg', '.png')):
        continue

    img_path = os.path.join(VIDEO_FRAMES_DIR, img_file)
    image = Image.open(img_path)
    orig_size = image.size
    tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        out_cls, out_seg, out_val = model(tensor)
        pred_label = torch.argmax(out_cls, dim=1).item()
        label_str = label_map[pred_label]
        val_norm = out_val.item()
        real_vals = denormalize(val_norm, label_str, MIN_MAX_PATH)

        pred_mask = torch.sigmoid(out_seg).squeeze().cpu().numpy()
        pred_mask = cv2.resize(pred_mask, orig_size[::-1])
        pred_mask = (pred_mask > 0.2).astype(np.uint8) * 255  # lowered threshold to 0.2

    # Find contours
    contours, _ = cv2.findContours(pred_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    mask_canvas = np.zeros_like(pred_mask)

    if len(contours) > 0:
        cnt = max(contours, key=cv2.contourArea)
        if label_str in ["head", "abdomen"] and len(cnt) >= 5:
            ellipse = cv2.fitEllipse(cnt)
            if ellipse[1][0] > 0 and ellipse[1][1] > 0:
                cv2.ellipse(mask_canvas, ellipse, 255, thickness=2)
            else:
                print(f"⚠️ Invalid ellipse dimensions in {img_file}, skipping ellipse draw.")
        elif label_str == "femur" and len(cnt) >= 3:
            # Option 1: Convex hull
            hull = cv2.convexHull(cnt)
            cv2.drawContours(mask_canvas, [hull], -1, 255, thickness=2)

            # Option 2 (alternative): filled contour if you prefer a region mask
            # cv2.drawContours(mask_canvas, [cnt], -1, 255, thickness=cv2.FILLED)
    else:
        print(f"⚠️ No contour found in {img_file}, skipping drawing.")

    # Save mask
    mask_name = img_file.replace(".jpg", "_mask.png").replace(".png", "_mask.png")
    cv2.imwrite(os.path.join(OUTPUT_MASK_DIR, mask_name), mask_canvas)

    for biom_name, val in real_vals.items():
        results.append({"image": img_file, "plane": label_str, "type": biom_name, "value": val})

pd.DataFrame(results).to_csv(OUTPUT_CSV_PATH, index=False)
print("✅ Contour-fitting pseudo-label generation complete.")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12240\2242615945.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
# ⚠️ No contour found in seq_000_frame_0007.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0008.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0009.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0010.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0011.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0013.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0015.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0016.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0017.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0018.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0019.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0022.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0024.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0025.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0028.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0031.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0032.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0038.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0040.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0041.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0044.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0045.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0046.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0047.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0048.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0054.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0055.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0056.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0057.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0058.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0059.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0060.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0068.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0069.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0071.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0072.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0073.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0077.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0078.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0080.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0081.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0082.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0083.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0084.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0090.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0093.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0095.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0110.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0111.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0113.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0120.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0121.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0122.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0130.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0142.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0157.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0158.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0159.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0160.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0162.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0163.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0165.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0166.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0167.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0169.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0170.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0173.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0174.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0175.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0176.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0179.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0207.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0208.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0209.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0210.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0211.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0212.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0213.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0214.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0216.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0217.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0288.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0293.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0294.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0295.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0296.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0297.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0298.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0299.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0300.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0301.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0302.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0303.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0304.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0305.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0306.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0307.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0308.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0309.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0310.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0311.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0314.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0315.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0316.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0317.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0318.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0319.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0320.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0321.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0322.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0323.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0324.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0325.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0326.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0327.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0333.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0336.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0337.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0338.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0339.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0340.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0341.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0342.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0359.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0364.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0368.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0369.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0370.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0387.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0388.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0389.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0390.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0391.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0392.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0393.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0395.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0396.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0399.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0400.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0401.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0406.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0407.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0408.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0409.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0410.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0411.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0412.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0413.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0414.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0415.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0416.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0417.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0418.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0419.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0420.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0421.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0422.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0423.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0424.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0425.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0426.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0427.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0428.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0429.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0430.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0431.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0433.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0434.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0435.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0441.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0511.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0512.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0516.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0517.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0518.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0520.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0521.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0522.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0548.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0549.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0553.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0554.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0555.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0557.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0558.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0559.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0561.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0562.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0563.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0564.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0565.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0566.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0567.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0568.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0569.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0571.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0572.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0574.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0586.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0587.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0588.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0603.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0606.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0607.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0608.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0616.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0617.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0618.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0619.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0634.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0635.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0644.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0645.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0646.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0647.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0648.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0650.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0656.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0657.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0659.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0660.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0663.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0666.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0668.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0669.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0670.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0671.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0675.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0679.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0680.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0681.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0682.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0684.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0685.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0686.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0687.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0688.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0689.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0696.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0699.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0700.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0701.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0702.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0703.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0704.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0705.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0706.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0710.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0711.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0712.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0713.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0714.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0715.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0716.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0717.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0718.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0719.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0720.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0725.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0726.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0727.png, skipping drawing.
# ⚠️ No contour found in seq_000_frame_0728.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0000.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0001.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0002.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0003.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0004.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0005.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0006.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0007.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0008.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0009.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0010.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0011.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0012.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0013.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0014.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0015.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0018.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0019.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0020.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0021.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0022.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0023.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0024.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0025.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0026.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0031.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0032.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0033.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0034.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0035.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0036.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0037.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0038.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0039.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0040.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0041.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0042.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0043.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0044.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0045.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0046.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0047.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0048.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0049.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0050.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0051.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0052.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0053.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0054.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0055.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0056.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0057.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0058.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0059.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0060.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0061.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0062.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0063.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0064.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0065.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0066.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0067.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0068.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0069.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0070.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_001_frame_0084.png, skipping ellipse draw.
# ⚠️ No contour found in seq_001_frame_0085.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0086.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0087.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0088.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0089.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0090.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0091.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0092.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0093.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0094.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0095.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0096.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0097.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0098.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0099.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0100.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0101.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0102.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0103.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0104.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0105.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0106.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0107.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0108.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0109.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0110.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0112.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0113.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0114.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0115.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0117.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0118.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0119.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0120.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0121.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0122.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0123.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0124.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0125.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0126.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0127.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0129.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0130.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0131.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0133.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0134.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0135.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0136.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0137.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0140.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0141.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0142.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0143.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0144.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0145.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0146.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0147.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0148.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0149.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0150.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0151.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0152.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0153.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0155.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0165.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0166.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0167.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0168.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0169.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0171.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0172.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0173.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0174.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0175.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0176.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0178.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0179.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0180.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0181.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0182.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0183.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0184.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0185.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0188.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0189.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0192.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0193.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0196.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0197.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0198.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0199.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0200.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0201.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_001_frame_0204.png, skipping ellipse draw.
# ⚠️ No contour found in seq_001_frame_0206.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0207.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0208.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0209.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0210.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0211.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0212.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0214.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0218.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0219.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0220.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0222.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0224.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0225.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0226.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0235.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0240.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0241.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0242.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0254.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0259.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0260.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0263.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0265.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0315.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0317.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0321.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0326.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0327.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0328.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0329.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0340.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0354.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0356.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0357.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0360.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0361.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0362.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0363.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0366.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0368.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0369.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0370.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0371.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0372.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0373.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0374.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0377.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0380.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0381.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0382.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0383.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0384.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0385.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0386.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0387.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0388.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0389.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0391.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0392.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0395.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0396.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0397.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0398.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0399.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0400.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0401.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0402.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0403.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0404.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0405.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0406.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0407.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0408.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0409.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0410.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0411.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0412.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0413.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0414.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0415.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0416.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0417.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0426.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0427.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0428.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0429.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0430.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0431.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0432.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0433.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0434.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0435.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0436.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0437.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0438.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0439.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0440.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0441.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0445.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0446.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0447.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0448.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0449.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0450.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0451.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0453.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0454.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0455.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0456.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0457.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0458.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0459.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0460.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0461.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0462.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0463.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0464.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0465.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0466.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0467.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0470.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0471.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0472.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0473.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0474.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0475.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0476.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0477.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0478.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0479.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0480.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0481.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0482.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0483.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0484.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0485.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0486.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0487.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0488.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0489.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0490.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0491.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0492.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0493.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0494.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0495.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_001_frame_0497.png, skipping ellipse draw.
# ⚠️ No contour found in seq_001_frame_0500.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_001_frame_0501.png, skipping ellipse draw.
# ⚠️ No contour found in seq_001_frame_0503.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_001_frame_0505.png, skipping ellipse draw.
# ⚠️ No contour found in seq_001_frame_0511.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0512.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0513.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0514.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0515.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0516.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0517.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0518.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0519.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0520.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0521.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0522.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0523.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0524.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0525.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0526.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0527.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0528.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0529.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0530.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0531.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0532.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0533.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0534.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0535.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0536.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0538.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0539.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0540.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0541.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0542.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0543.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0544.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0545.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0546.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0547.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0548.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0554.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0555.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0556.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0557.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0558.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0559.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0560.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0561.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0562.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0563.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0566.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0567.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0568.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0569.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0570.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0571.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0572.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0573.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0574.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0576.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0577.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0578.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0579.png, skipping drawing.
# ⚠️ No contour found in seq_001_frame_0580.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0000.png, skipping ellipse draw.
# ⚠️ No contour found in seq_002_frame_0003.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0004.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0005.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0006.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0008.png, skipping ellipse draw.
# ⚠️ No contour found in seq_002_frame_0009.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0010.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0012.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0013.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0016.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0017.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0018.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0065.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0068.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0070.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0071.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0072.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0074.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0076.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0077.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0078.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0080.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0084.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0085.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0086.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0088.png, skipping ellipse draw.
# ⚠️ No contour found in seq_002_frame_0095.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0096.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0097.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0098.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0099.png, skipping drawing.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0100.png, skipping ellipse draw.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0102.png, skipping ellipse draw.
# ⚠️ Invalid ellipse dimensions in seq_002_frame_0103.png, skipping ellipse draw.
# ⚠️ No contour found in seq_002_frame_0116.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0118.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0119.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0120.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0121.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0125.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0126.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0127.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0128.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0129.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0130.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0147.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0148.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0177.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0180.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0181.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0182.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0183.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0184.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0185.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0186.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0187.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0188.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0189.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0192.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0193.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0194.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0195.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0196.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0197.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0205.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0206.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0207.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0208.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0209.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0210.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0211.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0212.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0213.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0214.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0215.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0216.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0220.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0221.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0226.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0227.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0228.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0229.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0230.png, skipping drawing.
# ⚠️ No contour found in seq_002_frame_0231.png, skipping drawing.
# ...
# ⚠️ No contour found in seq_082_frame_0047.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0048.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0049.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0050.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0051.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0052.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0053.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0054.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0055.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0056.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0057.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0071.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0072.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0073.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0074.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0075.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0076.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0077.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0078.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0079.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0080.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0081.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0082.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0083.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0084.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0085.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0086.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0087.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0088.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0096.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0106.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0107.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0108.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0109.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0110.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0115.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0116.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0122.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0123.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0125.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0126.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0127.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0128.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0129.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0130.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0131.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0132.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0133.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0134.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0135.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0136.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0137.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0138.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0142.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0143.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0144.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0145.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0146.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0147.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0148.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0149.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0150.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0151.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0152.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0153.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0154.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0155.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0156.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0157.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0158.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0159.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0160.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0161.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0162.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0163.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0164.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0165.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0166.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0168.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0169.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0170.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0184.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0185.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0189.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0190.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0191.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0192.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0193.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0194.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0195.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0196.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0197.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0198.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0200.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0201.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0202.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0203.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0204.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0205.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0206.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0207.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0208.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0209.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0210.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0211.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0212.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0213.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0214.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0215.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0216.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0217.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0218.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0219.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0220.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0221.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0222.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0223.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0224.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0225.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0226.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0227.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0228.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0229.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0230.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0231.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0232.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0233.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0234.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0236.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0237.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0238.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0239.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0240.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0241.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0242.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0243.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0244.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0245.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0249.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0250.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0264.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0265.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0266.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0268.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0269.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0270.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0271.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0272.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0273.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0274.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0275.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0276.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0277.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0278.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0279.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0280.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0281.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0282.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0283.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0284.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0285.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0286.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0287.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0288.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0289.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0290.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0291.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0292.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0293.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0296.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0297.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0298.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0299.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0300.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0301.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0302.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0303.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0304.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0305.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0306.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0308.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0309.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0311.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0316.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0319.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0325.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0326.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0327.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0328.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0335.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0338.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0346.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0347.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0348.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0349.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0350.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0351.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0352.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0353.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0354.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0355.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0356.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0357.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0358.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0359.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0360.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0361.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0362.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0363.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0377.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0378.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0379.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0380.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0381.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0382.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0383.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0384.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0385.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0386.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0387.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0388.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0389.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0390.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0391.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0396.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0397.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0398.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0410.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0411.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0412.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0413.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0414.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0415.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0416.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0420.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0421.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0422.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0423.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0430.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0431.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0432.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0433.png, skipping drawing.
# ⚠️ No contour found in seq_082_frame_0434.png, skipping drawing.
# ⚠️ No contour found in seq_083_frame_0017.png, skipping drawing.
# ⚠️ No contour found in seq_083_frame_0129.png, skipping drawing.
# ✅ Contour-fitting pseudo-label generation complete.
