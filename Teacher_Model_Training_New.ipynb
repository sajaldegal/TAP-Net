# %%
# Teacher Model: Multi-Task (Classification + Segmentation + Regression with Normalized Output)
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as T
from torchvision.transforms import functional as TF
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import pandas as pd
import os
import random

class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ConvBlock, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class TeacherNet(nn.Module):
    def __init__(self, in_channels=1, n_classes=3):
        super(TeacherNet, self).__init__()
        filters = [64, 128, 256, 512]

        self.encoder1 = ConvBlock(in_channels, filters[0])
        self.pool1 = nn.MaxPool2d(2)
        self.encoder2 = ConvBlock(filters[0], filters[1])
        self.pool2 = nn.MaxPool2d(2)
        self.encoder3 = ConvBlock(filters[1], filters[2])
        self.pool3 = nn.MaxPool2d(2)
        self.encoder4 = ConvBlock(filters[2], filters[3])
        self.pool4 = nn.MaxPool2d(2)

        self.bottleneck = ConvBlock(filters[3], filters[3])

        self.classifier = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(filters[3], 3)
        )

        self.up1 = nn.ConvTranspose2d(filters[3], filters[2], kernel_size=2, stride=2)
        self.decoder1 = ConvBlock(filters[2] + filters[3], filters[2])
        self.up2 = nn.ConvTranspose2d(filters[2], filters[1], kernel_size=2, stride=2)
        self.decoder2 = ConvBlock(filters[1] + filters[2], filters[1])
        self.up3 = nn.ConvTranspose2d(filters[1], filters[0], kernel_size=2, stride=2)
        self.decoder3 = ConvBlock(filters[0] + filters[1], filters[0])
        self.up4 = nn.ConvTranspose2d(filters[0], filters[0] // 2, kernel_size=2, stride=2)
        self.decoder4 = ConvBlock(filters[0] // 2, filters[0])
        self.segmentation_head = nn.Conv2d(filters[0], 1, kernel_size=1)

        self.regressor = nn.Sequential(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(filters[3], 1),
            nn.Sigmoid()  # Predict in range [0, 1]
        )

    def forward(self, x):
        e1 = self.encoder1(x)
        e2 = self.encoder2(self.pool1(e1))
        e3 = self.encoder3(self.pool2(e2))
        e4 = self.encoder4(self.pool3(e3))
        b = self.bottleneck(self.pool4(e4))

        plane_logits = self.classifier(b)

        d1 = self.up1(b)
        d1 = self.decoder1(torch.cat([d1, e4], dim=1))
        d2 = self.up2(d1)
        d2 = self.decoder2(torch.cat([d2, e3], dim=1))
        d3 = self.up3(d2)
        d3 = self.decoder3(torch.cat([d3, e2], dim=1))
        d4 = self.up4(d3)
        d4 = self.decoder4(d4)
        segmentation = self.segmentation_head(d4)

        value = self.regressor(b)

        return plane_logits, segmentation, value

# =========================
# NORMALIZATION SCRIPT
# =========================
def normalize_and_save():
    df = pd.read_csv("G:/Sajal_Data/Obj_4_Code/Teacher_model_training/data/kamra_teacher_expanded.csv")
    min_vals = df.groupby("type")["value"].min()
    max_vals = df.groupby("type")["value"].max()

    def normalize(row):
        min_val = min_vals[row["type"]]
        max_val = max_vals[row["type"]]
        return (row["value"] - min_val) / (max_val - min_val)

    df["value_norm"] = df.apply(normalize, axis=1)
    df.to_csv("kamra_measurements_normalized.csv", index=False)

    min_max_df = pd.DataFrame({"min": min_vals, "max": max_vals})
    min_max_df.to_csv("biometric_min_max.csv")

# =========================
# INFERENCE DENORMALIZATION
# =========================
def denormalize(value_norm, biom_type, min_max_path="biometric_min_max.csv"):
    min_max = pd.read_csv(min_max_path, index_col=0)
    row = min_max.loc[biom_type]
    return value_norm * (row["max"] - row["min"]) + row["min"]

# =========================
# DataLoader and Training Loop
# =========================
class RandomAugment:
    def __call__(self, image, mask):
        if random.random() > 0.5:
            image = TF.hflip(image)
            mask = TF.hflip(mask)
        if random.random() > 0.5:
            angle = random.uniform(-15, 15)
            image = TF.rotate(image, angle)
            mask = TF.rotate(mask, angle)
        return image, mask

class UltrasoundDataset(Dataset):
    def __init__(self, image_dir, mask_dir, csv_path, transform=None, augment=None):
        self.image_dir = image_dir
        self.mask_dir = mask_dir
        self.data = pd.read_csv(csv_path)
        self.transform = transform or T.Compose([T.Resize((224, 224)), T.ToTensor()])
        self.augment = augment

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        img_path = os.path.join(self.image_dir, row['image'])
        mask_path = os.path.join(self.mask_dir, row['image'].replace('.jpg', '_mask.png'))

        image = Image.open(img_path).convert('L')
        mask = Image.open(mask_path).convert('L')

        if self.augment:
            image, mask = self.augment(image, mask)

        image = self.transform(image)
        mask = self.transform(mask)

        label_map = {'head': 0, 'abdomen': 1, 'femur': 2}
        label = torch.tensor(label_map[row['plane'].lower()], dtype=torch.long)
        value = torch.tensor(row['value_norm'], dtype=torch.float32)

        return image, mask, label, value

# Run normalization once before training
normalize_and_save()

model = TeacherNet()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
cls_loss = nn.CrossEntropyLoss()
seg_loss = nn.BCEWithLogitsLoss()
reg_loss = nn.MSELoss()

train_dataset = UltrasoundDataset(
    "G:/Sajal_Data/Obj_4_Code/Teacher_model_training/data/images",
    "G:/Sajal_Data/Obj_4_Code/Teacher_model_training/data/masks",
    "kamra_measurements_normalized.csv",
    augment=RandomAugment()
)
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

for epoch in range(100):
    model.train()
    total_loss = 0
    for img, mask, label, value in train_loader:
        img, mask, label, value = img.to(device), mask.to(device), label.to(device), value.to(device)

        optimizer.zero_grad()
        out_cls, out_seg, out_val = model(img)

        loss_c = cls_loss(out_cls, label)
        loss_s = seg_loss(out_seg, mask)
        loss_r = reg_loss(out_val.view(-1), value.view(-1))

        loss = loss_c + loss_s + 0.01 * loss_r
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}: Total={loss.item():.2f} | Cls={loss_c.item():.2f} | Seg={loss_s.item():.2f} | Reg={loss_r.item():.2f}")

# Save the model
torch.save(model.state_dict(), "teacher_model.pth")
# Out:
# Epoch 1: Total=1.27 | Cls=0.69 | Seg=0.58 | Reg=0.24
# Epoch 2: Total=1.02 | Cls=0.56 | Seg=0.46 | Reg=0.11
# Epoch 3: Total=2.36 | Cls=1.95 | Seg=0.40 | Reg=0.01
# Epoch 4: Total=0.95 | Cls=0.54 | Seg=0.41 | Reg=0.30
# Epoch 5: Total=0.85 | Cls=0.46 | Seg=0.38 | Reg=0.14
# Epoch 6: Total=0.87 | Cls=0.47 | Seg=0.40 | Reg=0.15
# Epoch 7: Total=0.80 | Cls=0.47 | Seg=0.33 | Reg=0.10
# Epoch 8: Total=0.74 | Cls=0.42 | Seg=0.31 | Reg=0.12
# Epoch 9: Total=1.85 | Cls=1.54 | Seg=0.30 | Reg=0.02
# Epoch 10: Total=0.78 | Cls=0.47 | Seg=0.30 | Reg=0.29
# Epoch 11: Total=1.87 | Cls=1.60 | Seg=0.27 | Reg=0.02
# Epoch 12: Total=2.31 | Cls=2.04 | Seg=0.27 | Reg=0.02
# Epoch 13: Total=2.13 | Cls=1.88 | Seg=0.25 | Reg=0.01
# Epoch 14: Total=1.80 | Cls=1.54 | Seg=0.26 | Reg=0.01
# Epoch 15: Total=0.72 | Cls=0.48 | Seg=0.23 | Reg=0.30
# Epoch 16: Total=2.25 | Cls=2.03 | Seg=0.23 | Reg=0.01
# Epoch 17: Total=1.72 | Cls=1.49 | Seg=0.23 | Reg=0.06
# Epoch 18: Total=2.17 | Cls=1.96 | Seg=0.21 | Reg=0.09
# Epoch 19: Total=1.61 | Cls=1.41 | Seg=0.20 | Reg=0.13
# Epoch 20: Total=0.72 | Cls=0.50 | Seg=0.21 | Reg=0.30
# Epoch 21: Total=1.76 | Cls=1.57 | Seg=0.18 | Reg=0.13
# Epoch 22: Total=0.67 | Cls=0.49 | Seg=0.18 | Reg=0.29
# Epoch 23: Total=1.69 | Cls=1.51 | Seg=0.17 | Reg=0.16
# Epoch 24: Total=0.58 | Cls=0.41 | Seg=0.17 | Reg=0.11
# Epoch 25: Total=0.55 | Cls=0.39 | Seg=0.16 | Reg=0.27
# Epoch 26: Total=0.56 | Cls=0.40 | Seg=0.16 | Reg=0.29
# Epoch 27: Total=0.49 | Cls=0.34 | Seg=0.15 | Reg=0.25
# Epoch 28: Total=0.49 | Cls=0.33 | Seg=0.15 | Reg=0.20
# Epoch 29: Total=0.59 | Cls=0.44 | Seg=0.14 | Reg=0.18
# Epoch 30: Total=1.64 | Cls=1.51 | Seg=0.13 | Reg=0.02
# Epoch 31: Total=0.45 | Cls=0.31 | Seg=0.14 | Reg=0.29
# Epoch 32: Total=2.27 | Cls=2.14 | Seg=0.13 | Reg=0.00
# Epoch 33: Total=1.39 | Cls=1.26 | Seg=0.12 | Reg=0.12
# Epoch 34: Total=0.55 | Cls=0.43 | Seg=0.12 | Reg=0.29
# Epoch 35: Total=0.55 | Cls=0.43 | Seg=0.12 | Reg=0.11
# Epoch 36: Total=0.54 | Cls=0.43 | Seg=0.11 | Reg=0.30
# Epoch 37: Total=2.15 | Cls=2.04 | Seg=0.11 | Reg=0.01
# Epoch 38: Total=1.48 | Cls=1.37 | Seg=0.10 | Reg=0.21
# Epoch 39: Total=0.43 | Cls=0.32 | Seg=0.11 | Reg=0.29
# Epoch 40: Total=1.87 | Cls=1.76 | Seg=0.11 | Reg=0.02
# Epoch 41: Total=1.26 | Cls=1.16 | Seg=0.10 | Reg=0.12
# Epoch 42: Total=0.58 | Cls=0.48 | Seg=0.09 | Reg=0.12
# Epoch 43: Total=0.54 | Cls=0.44 | Seg=0.10 | Reg=0.15
# Epoch 44: Total=0.41 | Cls=0.32 | Seg=0.09 | Reg=0.29
# Epoch 45: Total=0.50 | Cls=0.41 | Seg=0.09 | Reg=0.18
# Epoch 46: Total=0.49 | Cls=0.40 | Seg=0.09 | Reg=0.15
# Epoch 47: Total=0.45 | Cls=0.37 | Seg=0.09 | Reg=0.11
# Epoch 48: Total=0.49 | Cls=0.40 | Seg=0.08 | Reg=0.34
# Epoch 49: Total=1.59 | Cls=1.51 | Seg=0.08 | Reg=0.01
# Epoch 50: Total=1.59 | Cls=1.51 | Seg=0.08 | Reg=0.15
# Epoch 51: Total=0.55 | Cls=0.47 | Seg=0.08 | Reg=0.31
# Epoch 52: Total=1.77 | Cls=1.69 | Seg=0.09 | Reg=0.28
# Epoch 53: Total=1.51 | Cls=1.43 | Seg=0.08 | Reg=0.02
# Epoch 54: Total=0.41 | Cls=0.34 | Seg=0.07 | Reg=0.15
# Epoch 55: Total=0.55 | Cls=0.47 | Seg=0.07 | Reg=0.32
# Epoch 56: Total=0.44 | Cls=0.36 | Seg=0.07 | Reg=0.29
# Epoch 57: Total=0.35 | Cls=0.28 | Seg=0.07 | Reg=0.26
# Epoch 58: Total=2.35 | Cls=2.28 | Seg=0.06 | Reg=0.00
# Epoch 59: Total=0.37 | Cls=0.30 | Seg=0.07 | Reg=0.15
# Epoch 60: Total=0.42 | Cls=0.35 | Seg=0.07 | Reg=0.13
# Epoch 61: Total=0.55 | Cls=0.49 | Seg=0.06 | Reg=0.16
# Epoch 62: Total=0.54 | Cls=0.48 | Seg=0.06 | Reg=0.09
# Epoch 63: Total=0.49 | Cls=0.43 | Seg=0.06 | Reg=0.32
# Epoch 64: Total=1.97 | Cls=1.90 | Seg=0.07 | Reg=0.28
# Epoch 65: Total=1.51 | Cls=1.46 | Seg=0.05 | Reg=0.28
# Epoch 66: Total=1.21 | Cls=1.16 | Seg=0.05 | Reg=0.00
# Epoch 67: Total=0.37 | Cls=0.32 | Seg=0.05 | Reg=0.25
# Epoch 68: Total=2.15 | Cls=2.10 | Seg=0.05 | Reg=0.08
# Epoch 69: Total=0.48 | Cls=0.43 | Seg=0.05 | Reg=0.15
# Epoch 70: Total=1.66 | Cls=1.61 | Seg=0.05 | Reg=0.00
# Epoch 71: Total=2.30 | Cls=2.25 | Seg=0.05 | Reg=0.32
# Epoch 72: Total=1.35 | Cls=1.30 | Seg=0.06 | Reg=0.02
# Epoch 73: Total=1.62 | Cls=1.57 | Seg=0.05 | Reg=0.05
# Epoch 74: Total=0.41 | Cls=0.35 | Seg=0.06 | Reg=0.19
# Epoch 75: Total=1.95 | Cls=1.89 | Seg=0.06 | Reg=0.28
# Epoch 76: Total=0.62 | Cls=0.58 | Seg=0.04 | Reg=0.31
# Epoch 77: Total=1.45 | Cls=1.40 | Seg=0.05 | Reg=0.02
# Epoch 78: Total=1.31 | Cls=1.26 | Seg=0.05 | Reg=0.01
# Epoch 79: Total=1.08 | Cls=1.04 | Seg=0.04 | Reg=0.00
# Epoch 80: Total=0.33 | Cls=0.29 | Seg=0.04 | Reg=0.26
# Epoch 81: Total=1.91 | Cls=1.86 | Seg=0.05 | Reg=0.00
# Epoch 82: Total=1.95 | Cls=1.91 | Seg=0.04 | Reg=0.01
# Epoch 83: Total=0.45 | Cls=0.40 | Seg=0.05 | Reg=0.19
# Epoch 84: Total=1.28 | Cls=1.24 | Seg=0.04 | Reg=0.00
# Epoch 85: Total=0.32 | Cls=0.28 | Seg=0.04 | Reg=0.26
# Epoch 86: Total=1.91 | Cls=1.86 | Seg=0.05 | Reg=0.27
# Epoch 87: Total=0.40 | Cls=0.35 | Seg=0.05 | Reg=0.17
# Epoch 88: Total=1.41 | Cls=1.37 | Seg=0.03 | Reg=0.01
# Epoch 89: Total=0.68 | Cls=0.64 | Seg=0.04 | Reg=0.17
# Epoch 90: Total=1.86 | Cls=1.81 | Seg=0.05 | Reg=0.29
# Epoch 91: Total=0.56 | Cls=0.52 | Seg=0.04 | Reg=0.32
# Epoch 92: Total=1.54 | Cls=1.50 | Seg=0.04 | Reg=0.05
# Epoch 93: Total=0.37 | Cls=0.32 | Seg=0.05 | Reg=0.26
# Epoch 94: Total=0.58 | Cls=0.54 | Seg=0.04 | Reg=0.31
# Epoch 95: Total=0.28 | Cls=0.24 | Seg=0.04 | Reg=0.19
# Epoch 96: Total=2.07 | Cls=2.04 | Seg=0.03 | Reg=0.17
# Epoch 97: Total=0.47 | Cls=0.44 | Seg=0.03 | Reg=0.13
# Epoch 98: Total=0.52 | Cls=0.48 | Seg=0.03 | Reg=0.36
# Epoch 99: Total=0.25 | Cls=0.21 | Seg=0.04 | Reg=0.18
# Epoch 100: Total=0.52 | Cls=0.49 | Seg=0.03 | Reg=0.08
